# %% [markdown]
# # MarIA

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

# MarIA
model_name = "PlanTL-GOB-ES/roberta-base-bne"
print(f"Descargando modelo y tokenizer para MarIA...")

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=2)  # Ajusta num_labels según tus etiquetas

# Guardar localmente
tokenizer.save_pretrained("./MarIA_tokenizer")
model.save_pretrained("./MarIA_model")

print("MarIA descargado y guardado localmente.")
# Out:
# Descargando modelo y tokenizer para MarIA...
# tokenizer_config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/851k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/509k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.21M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/957 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at PlanTL-GOB-ES/roberta-base-bne and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# MarIA descargado y guardado localmente.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %% [markdown]
# # BERTIN

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

# BERTIN corregido
model_name = "bertin-project/bertin-roberta-base-spanish"
print(f"Descargando modelo y tokenizer para BERTIN...")

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=2)

# Guardar localmente
tokenizer.save_pretrained("./BERTIN_tokenizer")
model.save_pretrained("./BERTIN_model")

print("BERTIN descargado y guardado localmente.")
# Out:
# Descargando modelo y tokenizer para BERTIN...
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at bertin-project/bertin-roberta-base-spanish and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTIN descargado y guardado localmente.

# %% [markdown]
# # BETO

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

# BETO
model_name = "dccuchile/bert-base-spanish-wwm-cased"
print(f"Descargando modelo y tokenizer para BETO...")

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name, num_labels=2)

# Guardar localmente
tokenizer.save_pretrained("./BETO_tokenizer")
model.save_pretrained("./BETO_model")

print("BETO descargado y guardado localmente.")
# Out:
# Descargando modelo y tokenizer para BETO...
# tokenizer_config.json:   0%|          | 0.00/364 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/242k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/480k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/134 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BETO descargado y guardado localmente.
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
